# %%
import pylab
import matplotlib
# %matplotlib inline
# %pylab inline
import matplotlib.pyplot as plt
matplotlib.use('TkAgg')
matplotlib.rc('text', usetex=False)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
fig = plt.figure(figsize=(4, 16))
a1 = fig.add_subplot(411)   #top left
a2 = fig.add_subplot(412)   #top right
a3 = fig.add_subplot(413)   #bottom left
a4 = fig.add_subplot(414)   #bottom right
